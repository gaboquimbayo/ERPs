# %% [markdown]
# ## **ERPs**

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

# read data from excel file 
df = pd.read_excel('ET_ToDoModerations.xlsx', sheet_name='Tabelle1')

# convert columns to numeric
columns_to_convert = ['MeanEntI']
df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# choose target columns and set index to subject
df_filtered = df[['Subject','MeanEntI']]
df_filtered.set_index('Subject', inplace=True)
df_filtered.head()
# Out:
#          MeanEntI
# Subject
# 1        3.333333
# 3        4.000000
# 4        6.000000
# 5        3.000000
# 8        3.000000

# %%
# Load the files
P3_path = "ERP_Criterion_Good/Measures/P3_Latency.txt" # P3_MeanAmpl.txt or P3_Latency.txt
N2_path = "ERP_Criterion_Good/Measures/N2_Latency.txt" # N2_MeanAmpl.txt or N2_Latency.txt

p3 = pd.read_csv(P3_path, delim_whitespace=True)
n2 = pd.read_csv(N2_path, delim_whitespace=True)

# Extract the subject number from the file name
p3['Subject'] = p3['ERPset'].str.extract('(\d+)$').astype(int)
n2['Subject'] = n2['ERPset'].str.extract('(\d+)$').astype(int)

# Set the subject number as index
p3.set_index('Subject', inplace=True)
n2.set_index('Subject', inplace=True)
p3.head(11)
# Out:
#          bin1_Fp1  bin1_Fz  bin1_F3  bin1_F7  bin1_FT9  bin1_FC5  bin1_FC1  \
# Subject
# 1           300.0    500.0    364.0    380.0     376.0     380.0     468.0
# 3           420.0    320.0    300.0    300.0     476.0     300.0     304.0
# 4           300.0    372.0    300.0    300.0     300.0     368.0     348.0
# 5           452.0    500.0    372.0    396.0     396.0     372.0     372.0
# 8           408.0    472.0    468.0    460.0     416.0     420.0     496.0
# 12          300.0    300.0    300.0    500.0     300.0     300.0     300.0
# 15          300.0    376.0    300.0    308.0     300.0     308.0     452.0
# 17          300.0    300.0    300.0    300.0     300.0     300.0     300.0
# 18          432.0    300.0    300.0    300.0     308.0     300.0     360.0
# 24          308.0    384.0    316.0    312.0     316.0     316.0     332.0
# 26          488.0    300.0    492.0    492.0     500.0     492.0     488.0
#
#          bin1_C3  bin1_T7  bin1_TP9  ...  bin3_Cz  bin3_C4  bin3_T8  \
# Subject                              ...
# 1          460.0    448.0     380.0  ...    344.0    332.0    500.0
# 3          300.0    300.0     300.0  ...    320.0    340.0    408.0
# 4          300.0    300.0     300.0  ...    476.0    500.0    500.0
# 5          368.0    372.0     416.0  ...    500.0    496.0    500.0
# 8          480.0    416.0     420.0  ...    300.0    380.0    356.0
# 12         304.0    412.0     492.0  ...    308.0    348.0    500.0
# 15         328.0    308.0     300.0  ...    448.0    440.0    440.0
# 17         300.0    304.0     468.0  ...    300.0    384.0    468.0
# 18         360.0    316.0     424.0  ...    360.0    360.0    300.0
# 24         328.0    312.0     500.0  ...    408.0    424.0    432.0
# 26         488.0    496.0     336.0  ...    300.0    300.0    324.0
#
#          bin3_FT10  bin3_FC6  bin3_FC2  bin3_F4  bin3_F8  bin3_Fp2  \
# Subject
# 1            320.0     336.0     340.0    340.0    500.0     300.0
# 3            408.0     408.0     324.0    320.0    400.0     452.0
# 4            496.0     476.0     364.0    500.0    300.0     496.0
# 5            500.0     500.0     500.0    500.0    496.0     460.0
# 8            300.0     468.0     420.0    300.0    300.0     300.0
# 12           500.0     348.0     364.0    352.0    500.0     500.0
# 15           448.0     500.0     440.0    444.0    392.0     500.0
# 17           452.0     380.0     300.0    360.0    364.0     364.0
# 18           416.0     300.0     360.0    380.0    400.0     416.0
# 24           428.0     372.0     420.0    428.0    432.0     496.0
# 26           300.0     300.0     316.0    500.0    360.0     368.0
#
#                       ERPset
# Subject
# 1        ERPSET_Good_CRB_001
# 3        ERPSET_Good_CRB_003
# 4        ERPSET_Good_CRB_004
# 5        ERPSET_Good_CRB_005
# 8        ERPSET_Good_CRB_008
# 12       ERPSET_Good_CRB_012
# 15       ERPSET_Good_CRB_015
# 17       ERPSET_Good_CRB_017
# 18       ERPSET_Good_CRB_018
# 24       ERPSET_Good_CRB_024
# 26       ERPSET_Good_CRB_026
#
# [11 rows x 97 columns]

# %%
# Merge the dataframes on the subject number
df_P3 = df_filtered.merge(p3, left_on='Subject', right_index=True)
df_N2 = df_filtered.merge(n2, left_on='Subject', right_index=True)

print(df_N2, "\n")
print("Number of subjects =", df_N2.shape[0])
# Out:
#          MeanEntI  bin1_Fp1  bin1_Fz  bin1_F3  bin1_F7  bin1_FT9  bin1_FC5  \
# Subject
# 1        3.333333     204.0    300.0    300.0    300.0     300.0     300.0
# 3        4.000000     200.0    200.0    200.0    200.0     300.0     200.0
# 4        6.000000     300.0    292.0    300.0    300.0     300.0     300.0
# 5        3.000000     300.0    300.0    300.0    200.0     200.0     200.0
# 8        3.000000     300.0    288.0    204.0    300.0     300.0     208.0
# 12       2.000000     236.0    300.0    300.0    240.0     300.0     300.0
# 15       5.666667     300.0    236.0    252.0    300.0     300.0     300.0
# 17       4.833333     300.0    204.0    200.0    300.0     300.0     300.0
# 18       2.833333     268.0    300.0    300.0    232.0     224.0     300.0
# 24       6.000000     240.0    280.0    240.0    236.0     208.0     240.0
# 26       6.000000     244.0    200.0    232.0    232.0     236.0     232.0
# 27       3.666667     300.0    300.0    296.0    288.0     288.0     288.0
# 28       2.166667     204.0    300.0    300.0    204.0     204.0     300.0
# 29       2.000000     200.0    264.0    300.0    300.0     300.0     300.0
# 32       2.000000     296.0    260.0    300.0    300.0     260.0     300.0
# 34       4.166667     216.0    300.0    300.0    224.0     224.0     224.0
# 35       4.833333     300.0    300.0    300.0    216.0     216.0     212.0
# 37       4.166667     288.0    300.0    296.0    292.0     296.0     288.0
# 40       6.000000     300.0    300.0    300.0    300.0     300.0     300.0
# 42       3.333333     240.0    200.0    248.0    252.0     256.0     252.0
# 43       1.500000     300.0    300.0    300.0    300.0     300.0     300.0
# 45       5.333333     300.0    292.0    292.0    288.0     288.0     288.0
# 49       5.000000     264.0    268.0    300.0    300.0     300.0     300.0
# 50       2.833333     204.0    200.0    200.0    200.0     200.0     200.0
# 54       3.000000     300.0    300.0    300.0    300.0     300.0     300.0
# 56       2.833333     200.0    296.0    204.0    200.0     200.0     200.0
# 58       5.333333     300.0    300.0    300.0    300.0     252.0     300.0
# 59       3.000000     296.0    300.0    292.0    212.0     212.0     264.0
# 60       3.666667     300.0    300.0    300.0    300.0     200.0     300.0
# 61       3.666667     264.0    300.0    280.0    280.0     300.0     280.0
# 62       2.333333     220.0    200.0    300.0    260.0     248.0     236.0
# 65       3.666667     300.0    240.0    300.0    300.0     300.0     296.0
# 66       3.833333     200.0    296.0    260.0    200.0     200.0     200.0
# 67       3.500000     200.0    256.0    212.0    296.0     212.0     216.0
# 68       2.333333     200.0    300.0    200.0    200.0     200.0     200.0
# 69       2.333333     292.0    200.0    288.0    288.0     276.0     284.0
# 70       4.000000     208.0    300.0    204.0    200.0     200.0     204.0
# 72       1.500000     300.0    300.0    300.0    300.0     300.0     300.0
# 74       3.333333     292.0    300.0    300.0    268.0     200.0     260.0
# 75       4.333333     200.0    300.0    200.0    200.0     200.0     200.0
# 76       3.333333     200.0    260.0    200.0    200.0     200.0     200.0
#
#          bin1_FC1  bin1_C3  bin1_T7  ...  bin3_Cz  bin3_C4  bin3_T8  \
# Subject                              ...
# 1           300.0    300.0    300.0  ...    272.0    280.0    212.0
# 3           200.0    200.0    200.0  ...    200.0    204.0    300.0
# 4           300.0    300.0    300.0  ...    224.0    224.0    220.0
# 5           300.0    200.0    200.0  ...    200.0    248.0    240.0
# 8           280.0    212.0    264.0  ...    300.0    252.0    300.0
# 12          300.0    200.0    300.0  ...    288.0    200.0    224.0
# 15          300.0    200.0    296.0  ...    216.0    228.0    224.0
# 17          208.0    300.0    228.0  ...    204.0    300.0    288.0
# 18          300.0    300.0    232.0  ...    200.0    200.0    200.0
# 24          252.0    248.0    236.0  ...    276.0    300.0    300.0
# 26          228.0    228.0    236.0  ...    300.0    300.0    300.0
# 27          300.0    300.0    284.0  ...    300.0    200.0    200.0
# 28          300.0    248.0    300.0  ...    244.0    276.0    220.0
# 29          300.0    300.0    300.0  ...    260.0    264.0    292.0
# 32          244.0    300.0    252.0  ...    200.0    200.0    268.0
# 34          300.0    280.0    228.0  ...    268.0    284.0    300.0
# 35          300.0    300.0    200.0  ...    248.0    244.0    240.0
# 37          300.0    280.0    288.0  ...    300.0    300.0    240.0
# 40          284.0    300.0    300.0  ...    268.0    200.0    200.0
# 42          300.0    288.0    252.0  ...    300.0    200.0    220.0
# 43          300.0    300.0    300.0  ...    300.0    272.0    200.0
# 45          288.0    284.0    280.0  ...    248.0    200.0    200.0
# 49          300.0    300.0    300.0  ...    300.0    252.0    244.0
# 50          200.0    200.0    200.0  ...    272.0    276.0    300.0
# 54          216.0    216.0    300.0  ...    200.0    200.0    292.0
# 56          288.0    288.0    200.0  ...    216.0    220.0    200.0
# 58          300.0    300.0    240.0  ...    300.0    208.0    200.0
# 59          272.0    212.0    260.0  ...    224.0    240.0    240.0
# 60          300.0    300.0    300.0  ...    212.0    208.0    224.0
# 61          264.0    264.0    300.0  ...    236.0    240.0    200.0
# 62          200.0    292.0    260.0  ...    200.0    204.0    208.0
# 65          292.0    284.0    288.0  ...    236.0    236.0    200.0
# 66          276.0    268.0    200.0  ...    300.0    208.0    212.0
# 67          252.0    228.0    212.0  ...    244.0    252.0    300.0
# 68          200.0    200.0    200.0  ...    208.0    284.0    300.0
# 69          300.0    300.0    272.0  ...    300.0    200.0    200.0
# 70          300.0    200.0    208.0  ...    300.0    292.0    296.0
# 72          300.0    300.0    300.0  ...    292.0    200.0    200.0
# 74          300.0    300.0    200.0  ...    220.0    200.0    268.0
# 75          260.0    244.0    200.0  ...    300.0    300.0    296.0
# 76          252.0    200.0    200.0  ...    276.0    288.0    296.0
#
#          bin3_FT10  bin3_FC6  bin3_FC2  bin3_F4  bin3_F8  bin3_Fp2  \
# Subject
# 1            228.0     272.0     216.0    212.0    272.0     216.0
# 3            300.0     296.0     200.0    200.0    300.0     200.0
# 4            228.0     236.0     236.0    224.0    300.0     236.0
# 5            244.0     240.0     300.0    300.0    232.0     300.0
# 8            300.0     300.0     260.0    200.0    300.0     300.0
# 12           244.0     224.0     284.0    224.0    236.0     240.0
# 15           224.0     224.0     224.0    224.0    232.0     216.0
# 17           280.0     300.0     200.0    200.0    296.0     200.0
# 18           200.0     200.0     260.0    200.0    260.0     300.0
# 24           300.0     300.0     300.0    300.0    300.0     228.0
# 26           300.0     300.0     300.0    252.0    224.0     284.0
# 27           200.0     200.0     300.0    200.0    200.0     248.0
# 28           200.0     280.0     284.0    284.0    204.0     204.0
# 29           288.0     268.0     248.0    256.0    276.0     280.0
# 32           268.0     256.0     200.0    248.0    268.0     264.0
# 34           300.0     300.0     288.0    300.0    300.0     216.0
# 35           300.0     232.0     244.0    216.0    264.0     268.0
# 37           236.0     236.0     300.0    236.0    236.0     236.0
# 40           208.0     208.0     228.0    208.0    208.0     208.0
# 42           220.0     208.0     200.0    200.0    212.0     216.0
# 43           248.0     252.0     300.0    248.0    248.0     252.0
# 45           200.0     200.0     200.0    200.0    200.0     200.0
# 49           240.0     248.0     260.0    260.0    244.0     244.0
# 50           268.0     264.0     272.0    276.0    272.0     300.0
# 54           292.0     296.0     200.0    300.0    300.0     300.0
# 56           200.0     200.0     212.0    200.0    200.0     200.0
# 58           200.0     204.0     300.0    264.0    200.0     252.0
# 59           240.0     240.0     200.0    240.0    240.0     240.0
# 60           264.0     264.0     260.0    288.0    220.0     220.0
# 61           200.0     208.0     232.0    228.0    204.0     200.0
# 62           204.0     204.0     200.0    200.0    204.0     200.0
# 65           200.0     200.0     232.0    200.0    200.0     200.0
# 66           224.0     212.0     248.0    200.0    216.0     212.0
# 67           296.0     256.0     248.0    200.0    300.0     300.0
# 68           284.0     296.0     300.0    300.0    296.0     296.0
# 69           200.0     300.0     200.0    200.0    200.0     200.0
# 70           300.0     296.0     300.0    292.0    300.0     296.0
# 72           200.0     200.0     268.0    200.0    200.0     200.0
# 74           300.0     224.0     300.0    200.0    296.0     200.0
# 75           296.0     300.0     208.0    296.0    228.0     296.0
# 76           292.0     288.0     276.0    280.0    292.0     288.0
#
#                       ERPset
# Subject
# 1        ERPSET_Good_CRB_001
# 3        ERPSET_Good_CRB_003
# 4        ERPSET_Good_CRB_004
# 5        ERPSET_Good_CRB_005
# 8        ERPSET_Good_CRB_008
# 12       ERPSET_Good_CRB_012
# 15       ERPSET_Good_CRB_015
# 17       ERPSET_Good_CRB_017
# 18       ERPSET_Good_CRB_018
# 24       ERPSET_Good_CRB_024
# 26       ERPSET_Good_CRB_026
# 27       ERPSET_Good_CRB_027
# 28       ERPSET_Good_CRB_028
# 29       ERPSET_Good_CRB_029
# 32       ERPSET_Good_CRB_032
# 34       ERPSET_Good_CRB_034
# 35       ERPSET_Good_CRB_035
# 37       ERPSET_Good_CRB_037
# 40       ERPSET_Good_CRB_040
# 42       ERPSET_Good_CRB_042
# 43       ERPSET_Good_CRB_043
# 45       ERPSET_Good_CRB_045
# 49       ERPSET_Good_CRB_049
# 50       ERPSET_Good_CRB_050
# 54       ERPSET_Good_CRB_054
# 56       ERPSET_Good_CRB_056
# 58       ERPSET_Good_CRB_058
# 59       ERPSET_Good_CRB_059
# 60       ERPSET_Good_CRB_060
# 61       ERPSET_Good_CRB_061
# 62       ERPSET_Good_CRB_062
# 65       ERPSET_Good_CRB_065
# 66       ERPSET_Good_CRB_066
# 67       ERPSET_Good_CRB_067
# 68       ERPSET_Good_CRB_068
# 69       ERPSET_Good_CRB_069
# 70       ERPSET_Good_CRB_070
# 72       ERPSET_Good_CRB_072
# 74       ERPSET_Good_CRB_074
# 75       ERPSET_Good_CRB_075
# 76       ERPSET_Good_CRB_076
#
# [41 rows x 98 columns]
#
# Number of subjects = 41

# %%
# name of the electrodes
electrodos_eeg = [
    "Fp1", "Fz", "F3", "F7", "FT9", "FC5", "FC1", "C3", "T7", "TP9",
    "CP5", "CP1", "Pz", "P3", "P7", "O1", "Oz", "O2", "P4", "P8",
    "TP10", "CP6", "CP2", "Cz", "C4", "T8", "FT10", "FC6", "FC2",
    "F4", "F8", "Fp2"
]

# %%
# to obtain p-values of predictors

n_bin = 3 # change this value to get the p-values of the other bins (e.g. 1, 2, 3)
prob_f_statistic_list = list()

for i in range(len(electrodos_eeg)):
    y = df_N2['MeanEntI'] # Change df_N2 to df_P3 to obtain the model for P3
    X = df_N2[f'bin{n_bin}_{electrodos_eeg[i]}'] # Change df_N2 to df_P3 to obtain the model for P3
    X = sm.add_constant(X) # adding a constant

    # fit the model
    model = sm.OLS(y, X)
    results = model.fit()
    
    prob_f_statistic_list.append(results.f_pvalue)

prob_f_statistic_list
# Out:
# [0.8602263596835505,
#  0.5224876224552184,
#  0.5435285039412157,
#  0.37313932484302603,
#  0.6513385231495925,
#  0.2733795303522449,
#  0.16066075923935483,
#  0.9299157911750856,
#  0.5966036109205108,
#  0.30682392863206087,
#  0.2363833981509898,
#  0.3130686024912678,
#  0.19969927873166055,
#  0.47640207635524334,
#  0.8997520575914019,
#  0.6789662185477082,
#  0.660513826897295,
#  0.6768163385606177,
#  0.553038606583582,
#  0.5809957429892745,
#  0.7234009109685218,
#  0.340712794776461,
#  0.012373137185612285,
#  0.5158427585323084,
#  0.3110363338747328,
#  0.6133470717510744,
#  0.536811197779163,
#  0.9522851166066593,
#  0.9866226932014045,
#  0.9009840339023867,
#  0.7668308696517964,
#  0.4746127113159381]

# %%
# model for once predictor

y = df_N2['MeanEntI'] # Change df_N2 to df_P3 to obtain the model for P3
X = df_N2[f'bin3_P3'] # Change df_N2 to df_P3 to obtain the model for P3
X = sm.add_constant(X) # adding a constant

# fit the model
model = sm.OLS(y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               MeanEntI   R-squared:                       0.160
# Model:                            OLS   Adj. R-squared:                  0.139
# Method:                 Least Squares   F-statistic:                     7.437
# Date:                Wed, 08 May 2024   Prob (F-statistic):            0.00953
# Time:                        09:02:54   Log-Likelihood:                -64.561
# No. Observations:                  41   AIC:                             133.1
# Df Residuals:                      39   BIC:                             136.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6809      0.187     19.637      0.000       3.302       4.060
# bin3_P3       -0.1236      0.045     -2.727      0.010      -0.215      -0.032
# ==============================================================================
# Omnibus:                        1.479   Durbin-Watson:                   1.722
# Prob(Omnibus):                  0.477   Jarque-Bera (JB):                1.267
# Skew:                           0.419   Prob(JB):                        0.531
# Kurtosis:                       2.798   Cond. No.                         4.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
